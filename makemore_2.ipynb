# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
words = open("names.txt", "r").read().splitlines()
char = sorted(set("".join(words)))
stoi = {s:i+1 for i, s in enumerate(char)}
stoi["."] = 0
itos = {i:s for s, i in stoi.items()}

# %%
# Hyperparameters
map_dim = 2     # Dimension of the mapping function
n_char = 3
layer_size = 100

# %%
xs = []
ys = []
for w in words:
    s = n_char * "."
    for chr in (w + "."):
        xs.append([stoi[ch] for ch in s])
        ys.append(stoi[chr])
        #print(f"{s} : {chr}")
        s = s[1:] + chr

xs = torch.tensor(xs)
ys = torch.tensor(ys)
n_element = ys.nelement()

# %%
xs[:10]
# Out:
# tensor([[ 0,  0,  0],
#         [ 0,  0,  5],
#         [ 0,  5, 13],
#         [ 5, 13, 13],
#         [ 0,  0,  0],
#         [ 0,  0, 15],
#         [ 0, 15, 12],
#         [15, 12,  9],
#         [12,  9, 22],
#         [ 9, 22,  9]])

# %%
# Character map generation
g = torch.Generator().manual_seed(1234)
ch_map = torch.randn((27, map_dim), generator=g, requires_grad=True)

# Layer generation
# 1st layer
W = torch.randn((layer_size, map_dim * n_char), generator=g, requires_grad=True)

# Final layer
W_f = torch.randn((27, layer_size), generator=g, requires_grad=True)

# %%
ch_map[[1, 2]]
# Out:
# tensor([[ 0.1631, -0.8817],
#         [ 0.0539,  0.6684]])

# %%
# Out:
# tensor(2.4722, grad_fn=<NegBackward0>)
# tensor(2.3857, grad_fn=<NegBackward0>)
# tensor(2.3973, grad_fn=<NegBackward0>)
# tensor(2.3816, grad_fn=<NegBackward0>)
# tensor(2.7368, grad_fn=<NegBackward0>)
# tensor(2.6459, grad_fn=<NegBackward0>)
# tensor(2.5991, grad_fn=<NegBackward0>)
# tensor(2.5126, grad_fn=<NegBackward0>)
# tensor(2.6749, grad_fn=<NegBackward0>)
# tensor(2.5175, grad_fn=<NegBackward0>)
# tensor(2.3689, grad_fn=<NegBackward0>)
# tensor(2.5893, grad_fn=<NegBackward0>)
# tensor(2.3925, grad_fn=<NegBackward0>)
# tensor(2.6333, grad_fn=<NegBackward0>)
# tensor(2.4254, grad_fn=<NegBackward0>)
# tensor(2.5138, grad_fn=<NegBackward0>)
# tensor(2.3741, grad_fn=<NegBackward0>)
# tensor(2.3890, grad_fn=<NegBackward0>)
# tensor(2.2943, grad_fn=<NegBackward0>)
# tensor(2.5716, grad_fn=<NegBackward0>)
# tensor(2.3495, grad_fn=<NegBackward0>)
# tensor(2.8455, grad_fn=<NegBackward0>)
# tensor(2.2416, grad_fn=<NegBackward0>)
# tensor(2.3574, grad_fn=<NegBackward0>)
# tensor(2.5268, grad_fn=<NegBackward0>)
# tensor(2.1680, grad_fn=<NegBackward0>)
# tensor(2.4337, grad_fn=<NegBackward0>)
# tensor(2.1477, grad_fn=<NegBackward0>)
# tensor(2.7271, grad_fn=<NegBackward0>)
# tensor(2.7064, grad_fn=<NegBackward0>)
# tensor(2.7937, grad_fn=<NegBackward0>)
# tensor(2.7069, grad_fn=<NegBackward0>)
# tensor(2.6237, grad_fn=<NegBackward0>)
# tensor(2.7433, grad_fn=<NegBackward0>)
# tensor(2.6209, grad_fn=<NegBackward0>)
# tensor(2.2738, grad_fn=<NegBackward0>)
# tensor(2.6949, grad_fn=<NegBackward0>)
# tensor(2.3991, grad_fn=<NegBackward0>)
# tensor(2.5535, grad_fn=<NegBackward0>)
# tensor(2.4871, grad_fn=<NegBackward0>)
# tensor(2.6502, grad_fn=<NegBackward0>)
# tensor(2.7652, grad_fn=<NegBackward0>)
# tensor(2.3369, grad_fn=<NegBackward0>)
# tensor(2.3669, grad_fn=<NegBackward0>)
# tensor(2.5328, grad_fn=<NegBackward0>)
# tensor(2.2297, grad_fn=<NegBackward0>)
# tensor(2.8545, grad_fn=<NegBackward0>)
# tensor(2.3511, grad_fn=<NegBackward0>)
# tensor(2.2780, grad_fn=<NegBackward0>)
# tensor(2.2854, grad_fn=<NegBackward0>)
# tensor(2.5063, grad_fn=<NegBackward0>)
# tensor(2.4589, grad_fn=<NegBackward0>)
# tensor(2.6248, grad_fn=<NegBackward0>)
# tensor(2.6464, grad_fn=<NegBackward0>)
# tensor(2.7354, grad_fn=<NegBackward0>)
# tensor(2.7738, grad_fn=<NegBackward0>)
# tensor(2.3667, grad_fn=<NegBackward0>)
# tensor(2.5229, grad_fn=<NegBackward0>)
# tensor(2.8017, grad_fn=<NegBackward0>)
# tensor(2.6917, grad_fn=<NegBackward0>)
# tensor(2.3958, grad_fn=<NegBackward0>)
# tensor(2.2579, grad_fn=<NegBackward0>)
# tensor(2.7352, grad_fn=<NegBackward0>)
# tensor(2.5107, grad_fn=<NegBackward0>)
# tensor(2.4538, grad_fn=<NegBackward0>)
# tensor(2.7638, grad_fn=<NegBackward0>)
# tensor(2.6132, grad_fn=<NegBackward0>)
# tensor(2.1192, grad_fn=<NegBackward0>)
# tensor(2.6933, grad_fn=<NegBackward0>)
# tensor(2.5739, grad_fn=<NegBackward0>)
# tensor(2.6686, grad_fn=<NegBackward0>)
# tensor(2.4448, grad_fn=<NegBackward0>)
# tensor(2.5419, grad_fn=<NegBackward0>)
# tensor(2.4010, grad_fn=<NegBackward0>)
# tensor(2.3404, grad_fn=<NegBackward0>)
# tensor(2.7310, grad_fn=<NegBackward0>)
# tensor(2.4506, grad_fn=<NegBackward0>)
# tensor(2.6802, grad_fn=<NegBackward0>)
# tensor(2.8159, grad_fn=<NegBackward0>)
# tensor(2.5024, grad_fn=<NegBackward0>)
# tensor(2.6569, grad_fn=<NegBackward0>)
# tensor(2.5608, grad_fn=<NegBackward0>)
# tensor(2.3604, grad_fn=<NegBackward0>)
# tensor(2.3857, grad_fn=<NegBackward0>)
# tensor(2.8621, grad_fn=<NegBackward0>)
# tensor(2.5007, grad_fn=<NegBackward0>)
# tensor(2.6642, grad_fn=<NegBackward0>)
# tensor(2.6636, grad_fn=<NegBackward0>)
# tensor(2.6016, grad_fn=<NegBackward0>)
# tensor(2.0376, grad_fn=<NegBackward0>)
# tensor(2.7370, grad_fn=<NegBackward0>)
# tensor(2.6232, grad_fn=<NegBackward0>)
# tensor(2.3572, grad_fn=<NegBackward0>)
# tensor(2.8586, grad_fn=<NegBackward0>)
# tensor(3.0157, grad_fn=<NegBackward0>)
# tensor(2.7390, grad_fn=<NegBackward0>)
# tensor(2.3739, grad_fn=<NegBackward0>)
# tensor(2.7111, grad_fn=<NegBackward0>)
# tensor(2.3434, grad_fn=<NegBackward0>)
# tensor(2.5621, grad_fn=<NegBackward0>)
# tensor(2.6241, grad_fn=<NegBackward0>)
# tensor(2.7798, grad_fn=<NegBackward0>)
# tensor(2.2406, grad_fn=<NegBackward0>)
# tensor(2.2824, grad_fn=<NegBackward0>)
# tensor(2.4703, grad_fn=<NegBackward0>)
# tensor(2.3612, grad_fn=<NegBackward0>)
# tensor(2.6556, grad_fn=<NegBackward0>)
# tensor(2.5452, grad_fn=<NegBackward0>)
# tensor(2.7237, grad_fn=<NegBackward0>)
# tensor(2.2679, grad_fn=<NegBackward0>)
# tensor(2.4094, grad_fn=<NegBackward0>)
# tensor(2.5665, grad_fn=<NegBackward0>)
# tensor(2.2579, grad_fn=<NegBackward0>)
# tensor(2.2333, grad_fn=<NegBackward0>)
# tensor(2.6424, grad_fn=<NegBackward0>)
# tensor(2.3514, grad_fn=<NegBackward0>)
# tensor(2.4479, grad_fn=<NegBackward0>)
# tensor(2.5570, grad_fn=<NegBackward0>)
# tensor(2.6891, grad_fn=<NegBackward0>)
# tensor(2.5020, grad_fn=<NegBackward0>)
# tensor(2.4671, grad_fn=<NegBackward0>)
# tensor(2.5636, grad_fn=<NegBackward0>)
# tensor(2.3030, grad_fn=<NegBackward0>)
# tensor(2.7254, grad_fn=<NegBackward0>)
# tensor(2.5533, grad_fn=<NegBackward0>)
# tensor(2.5766, grad_fn=<NegBackward0>)
# tensor(2.6317, grad_fn=<NegBackward0>)
# tensor(2.5648, grad_fn=<NegBackward0>)
# tensor(2.3076, grad_fn=<NegBackward0>)
# tensor(2.2763, grad_fn=<NegBackward0>)
# tensor(2.3350, grad_fn=<NegBackward0>)
# tensor(2.2853, grad_fn=<NegBackward0>)
# tensor(2.4875, grad_fn=<NegBackward0>)
# tensor(2.3642, grad_fn=<NegBackward0>)
# tensor(2.5403, grad_fn=<NegBackward0>)
# tensor(2.4627, grad_fn=<NegBackward0>)
# tensor(2.3986, grad_fn=<NegBackward0>)
# tensor(2.5539, grad_fn=<NegBackward0>)
# tensor(2.5944, grad_fn=<NegBackward0>)
# tensor(2.4630, grad_fn=<NegBackward0>)
# tensor(2.3271, grad_fn=<NegBackward0>)
# tensor(2.6417, grad_fn=<NegBackward0>)
# tensor(2.7988, grad_fn=<NegBackward0>)
# tensor(2.4748, grad_fn=<NegBackward0>)
# tensor(2.8533, grad_fn=<NegBackward0>)
# tensor(2.6482, grad_fn=<NegBackward0>)
# tensor(2.4503, grad_fn=<NegBackward0>)
# tensor(2.6975, grad_fn=<NegBackward0>)
# tensor(2.4346, grad_fn=<NegBackward0>)
# tensor(2.3389, grad_fn=<NegBackward0>)
# tensor(2.2163, grad_fn=<NegBackward0>)
# tensor(2.3104, grad_fn=<NegBackward0>)
# tensor(2.4015, grad_fn=<NegBackward0>)
# tensor(2.2970, grad_fn=<NegBackward0>)
# tensor(2.5416, grad_fn=<NegBackward0>)
# tensor(2.3185, grad_fn=<NegBackward0>)
# tensor(2.0509, grad_fn=<NegBackward0>)
# tensor(2.6068, grad_fn=<NegBackward0>)
# tensor(2.5189, grad_fn=<NegBackward0>)
# tensor(2.7358, grad_fn=<NegBackward0>)
# tensor(2.4821, grad_fn=<NegBackward0>)
# tensor(2.1383, grad_fn=<NegBackward0>)
# tensor(2.5777, grad_fn=<NegBackward0>)
# tensor(2.4338, grad_fn=<NegBackward0>)
# tensor(2.3709, grad_fn=<NegBackward0>)
# tensor(2.4403, grad_fn=<NegBackward0>)
# tensor(2.5991, grad_fn=<NegBackward0>)
# tensor(2.4256, grad_fn=<NegBackward0>)
# tensor(2.5317, grad_fn=<NegBackward0>)
# tensor(2.3115, grad_fn=<NegBackward0>)
# tensor(2.4903, grad_fn=<NegBackward0>)
# tensor(2.4409, grad_fn=<NegBackward0>)
# tensor(2.6396, grad_fn=<NegBackward0>)
# tensor(2.5110, grad_fn=<NegBackward0>)
# tensor(2.5819, grad_fn=<NegBackward0>)
# tensor(2.5140, grad_fn=<NegBackward0>)
# tensor(2.7965, grad_fn=<NegBackward0>)
# tensor(2.5378, grad_fn=<NegBackward0>)
# tensor(2.7315, grad_fn=<NegBackward0>)
# tensor(2.3720, grad_fn=<NegBackward0>)
# tensor(2.5600, grad_fn=<NegBackward0>)
# tensor(2.2930, grad_fn=<NegBackward0>)
# tensor(2.3770, grad_fn=<NegBackward0>)
# tensor(2.4226, grad_fn=<NegBackward0>)
# tensor(2.3749, grad_fn=<NegBackward0>)
# tensor(2.3737, grad_fn=<NegBackward0>)
# tensor(2.4371, grad_fn=<NegBackward0>)
# tensor(2.4869, grad_fn=<NegBackward0>)
# tensor(2.2821, grad_fn=<NegBackward0>)
# tensor(2.6883, grad_fn=<NegBackward0>)
# tensor(2.6345, grad_fn=<NegBackward0>)
# tensor(2.5493, grad_fn=<NegBackward0>)
# tensor(2.6209, grad_fn=<NegBackward0>)
# tensor(2.2348, grad_fn=<NegBackward0>)
# tensor(2.6204, grad_fn=<NegBackward0>)
# tensor(2.4923, grad_fn=<NegBackward0>)
# tensor(2.4123, grad_fn=<NegBackward0>)
# tensor(2.1958, grad_fn=<NegBackward0>)
# tensor(2.6807, grad_fn=<NegBackward0>)
# tensor(2.5670, grad_fn=<NegBackward0>)
# tensor(2.3743, grad_fn=<NegBackward0>)
# tensor(2.6752, grad_fn=<NegBackward0>)
# tensor(2.7030, grad_fn=<NegBackward0>)
# tensor(2.5389, grad_fn=<NegBackward0>)
# tensor(2.5327, grad_fn=<NegBackward0>)
# tensor(2.5943, grad_fn=<NegBackward0>)
# tensor(2.6721, grad_fn=<NegBackward0>)
# tensor(2.5839, grad_fn=<NegBackward0>)
# tensor(2.4161, grad_fn=<NegBackward0>)
# tensor(2.2608, grad_fn=<NegBackward0>)
# tensor(2.6652, grad_fn=<NegBackward0>)
# tensor(2.4152, grad_fn=<NegBackward0>)
# tensor(2.3646, grad_fn=<NegBackward0>)
# tensor(2.5383, grad_fn=<NegBackward0>)
# tensor(2.5346, grad_fn=<NegBackward0>)
# tensor(2.7935, grad_fn=<NegBackward0>)
# tensor(2.3845, grad_fn=<NegBackward0>)
# tensor(2.3931, grad_fn=<NegBackward0>)
# tensor(2.5725, grad_fn=<NegBackward0>)
# tensor(2.7421, grad_fn=<NegBackward0>)
# tensor(2.4809, grad_fn=<NegBackward0>)
# tensor(2.7650, grad_fn=<NegBackward0>)
# tensor(2.3945, grad_fn=<NegBackward0>)
# tensor(2.2840, grad_fn=<NegBackward0>)
# tensor(2.5674, grad_fn=<NegBackward0>)
# tensor(2.1243, grad_fn=<NegBackward0>)
# tensor(2.3616, grad_fn=<NegBackward0>)
# tensor(2.4279, grad_fn=<NegBackward0>)
# tensor(2.3062, grad_fn=<NegBackward0>)
# tensor(2.3805, grad_fn=<NegBackward0>)
# tensor(2.5757, grad_fn=<NegBackward0>)
# tensor(2.5426, grad_fn=<NegBackward0>)
# tensor(2.2261, grad_fn=<NegBackward0>)
# tensor(2.4292, grad_fn=<NegBackward0>)
# tensor(2.7734, grad_fn=<NegBackward0>)
# tensor(2.7957, grad_fn=<NegBackward0>)
# tensor(2.6244, grad_fn=<NegBackward0>)
# tensor(2.4438, grad_fn=<NegBackward0>)
# tensor(2.2396, grad_fn=<NegBackward0>)
# tensor(2.2423, grad_fn=<NegBackward0>)
# tensor(2.5581, grad_fn=<NegBackward0>)
# tensor(2.6739, grad_fn=<NegBackward0>)
# tensor(2.4714, grad_fn=<NegBackward0>)
# tensor(2.4052, grad_fn=<NegBackward0>)
# tensor(2.5822, grad_fn=<NegBackward0>)
# tensor(2.5971, grad_fn=<NegBackward0>)
# tensor(2.6384, grad_fn=<NegBackward0>)
# tensor(2.4113, grad_fn=<NegBackward0>)
# tensor(2.3676, grad_fn=<NegBackward0>)
# tensor(2.6562, grad_fn=<NegBackward0>)
# tensor(2.5718, grad_fn=<NegBackward0>)
# tensor(2.7963, grad_fn=<NegBackward0>)
# tensor(2.7092, grad_fn=<NegBackward0>)
# tensor(2.4403, grad_fn=<NegBackward0>)
# tensor(2.8875, grad_fn=<NegBackward0>)
# tensor(2.6752, grad_fn=<NegBackward0>)
# tensor(2.6226, grad_fn=<NegBackward0>)
# tensor(2.5059, grad_fn=<NegBackward0>)
# tensor(2.2588, grad_fn=<NegBackward0>)
# tensor(2.4245, grad_fn=<NegBackward0>)
# tensor(2.4836, grad_fn=<NegBackward0>)
# tensor(2.2641, grad_fn=<NegBackward0>)
# tensor(2.3430, grad_fn=<NegBackward0>)
# tensor(2.3638, grad_fn=<NegBackward0>)
# tensor(2.4203, grad_fn=<NegBackward0>)
# tensor(2.6318, grad_fn=<NegBackward0>)
# tensor(2.6079, grad_fn=<NegBackward0>)
# tensor(2.5729, grad_fn=<NegBackward0>)
# tensor(2.6795, grad_fn=<NegBackward0>)
# tensor(2.4573, grad_fn=<NegBackward0>)
# tensor(2.2237, grad_fn=<NegBackward0>)
# tensor(2.5509, grad_fn=<NegBackward0>)
# tensor(2.4758, grad_fn=<NegBackward0>)
# tensor(2.4064, grad_fn=<NegBackward0>)
# tensor(2.1304, grad_fn=<NegBackward0>)
# tensor(2.5918, grad_fn=<NegBackward0>)
# tensor(2.6755, grad_fn=<NegBackward0>)
# tensor(2.5512, grad_fn=<NegBackward0>)
# tensor(2.4779, grad_fn=<NegBackward0>)
# tensor(2.6147, grad_fn=<NegBackward0>)
# tensor(2.3045, grad_fn=<NegBackward0>)
# tensor(2.4277, grad_fn=<NegBackward0>)
# tensor(2.8002, grad_fn=<NegBackward0>)
# tensor(2.2655, grad_fn=<NegBackward0>)
# tensor(2.2230, grad_fn=<NegBackward0>)
# tensor(2.7718, grad_fn=<NegBackward0>)
# tensor(2.5919, grad_fn=<NegBackward0>)
# tensor(2.6945, grad_fn=<NegBackward0>)
# tensor(2.4016, grad_fn=<NegBackward0>)
# tensor(2.5683, grad_fn=<NegBackward0>)
# tensor(2.3125, grad_fn=<NegBackward0>)
# tensor(2.4562, grad_fn=<NegBackward0>)
# tensor(2.2621, grad_fn=<NegBackward0>)
# tensor(2.5434, grad_fn=<NegBackward0>)
# tensor(2.7455, grad_fn=<NegBackward0>)
# tensor(2.7479, grad_fn=<NegBackward0>)
# tensor(2.6826, grad_fn=<NegBackward0>)
# tensor(2.8547, grad_fn=<NegBackward0>)
# tensor(2.5208, grad_fn=<NegBackward0>)
# tensor(2.7322, grad_fn=<NegBackward0>)
# tensor(2.2924, grad_fn=<NegBackward0>)
# tensor(2.6291, grad_fn=<NegBackward0>)
# tensor(2.6006, grad_fn=<NegBackward0>)
# tensor(2.6180, grad_fn=<NegBackward0>)
# tensor(2.3506, grad_fn=<NegBackward0>)
# tensor(2.2800, grad_fn=<NegBackward0>)
# tensor(2.6462, grad_fn=<NegBackward0>)
# tensor(2.4550, grad_fn=<NegBackward0>)
# tensor(2.6588, grad_fn=<NegBackward0>)
# tensor(2.4642, grad_fn=<NegBackward0>)
# tensor(2.4902, grad_fn=<NegBackward0>)
# tensor(2.5676, grad_fn=<NegBackward0>)
# tensor(2.7315, grad_fn=<NegBackward0>)
# tensor(2.2383, grad_fn=<NegBackward0>)
# tensor(2.3423, grad_fn=<NegBackward0>)
# tensor(2.4723, grad_fn=<NegBackward0>)
# tensor(2.5373, grad_fn=<NegBackward0>)
# tensor(2.2238, grad_fn=<NegBackward0>)
# tensor(2.7350, grad_fn=<NegBackward0>)
# tensor(2.3000, grad_fn=<NegBackward0>)
# tensor(2.4953, grad_fn=<NegBackward0>)
# tensor(2.5292, grad_fn=<NegBackward0>)
# tensor(2.6760, grad_fn=<NegBackward0>)
# tensor(2.1553, grad_fn=<NegBackward0>)
# tensor(2.4566, grad_fn=<NegBackward0>)
# tensor(2.7907, grad_fn=<NegBackward0>)
# tensor(2.2718, grad_fn=<NegBackward0>)
# tensor(2.5272, grad_fn=<NegBackward0>)
# tensor(2.7045, grad_fn=<NegBackward0>)
# tensor(2.6674, grad_fn=<NegBackward0>)
# tensor(2.5905, grad_fn=<NegBackward0>)
# tensor(2.6378, grad_fn=<NegBackward0>)
# tensor(2.5784, grad_fn=<NegBackward0>)
# tensor(2.6643, grad_fn=<NegBackward0>)
# tensor(2.3774, grad_fn=<NegBackward0>)
# tensor(2.2824, grad_fn=<NegBackward0>)
# tensor(2.7229, grad_fn=<NegBackward0>)
# tensor(2.5134, grad_fn=<NegBackward0>)
# tensor(2.2712, grad_fn=<NegBackward0>)
# tensor(2.3182, grad_fn=<NegBackward0>)
# tensor(2.6126, grad_fn=<NegBackward0>)
# tensor(2.4539, grad_fn=<NegBackward0>)
# tensor(2.7944, grad_fn=<NegBackward0>)
# tensor(2.4797, grad_fn=<NegBackward0>)
# tensor(2.9945, grad_fn=<NegBackward0>)
# tensor(2.5515, grad_fn=<NegBackward0>)
# tensor(2.9158, grad_fn=<NegBackward0>)
# tensor(2.4043, grad_fn=<NegBackward0>)
# tensor(2.6409, grad_fn=<NegBackward0>)
# tensor(2.7519, grad_fn=<NegBackward0>)
# tensor(2.7678, grad_fn=<NegBackward0>)
# tensor(2.5145, grad_fn=<NegBackward0>)
# tensor(2.4015, grad_fn=<NegBackward0>)
# tensor(2.6003, grad_fn=<NegBackward0>)
# tensor(2.5132, grad_fn=<NegBackward0>)
# tensor(2.5490, grad_fn=<NegBackward0>)
# tensor(2.6746, grad_fn=<NegBackward0>)
# tensor(3.3017, grad_fn=<NegBackward0>)
# tensor(2.5125, grad_fn=<NegBackward0>)
# tensor(2.6876, grad_fn=<NegBackward0>)
# tensor(2.7357, grad_fn=<NegBackward0>)
# tensor(2.5582, grad_fn=<NegBackward0>)
# tensor(2.6462, grad_fn=<NegBackward0>)
# tensor(2.6111, grad_fn=<NegBackward0>)
# tensor(2.4260, grad_fn=<NegBackward0>)
# tensor(2.5337, grad_fn=<NegBackward0>)
# tensor(2.4206, grad_fn=<NegBackward0>)
# tensor(2.3289, grad_fn=<NegBackward0>)
# tensor(2.5513, grad_fn=<NegBackward0>)
# tensor(2.2713, grad_fn=<NegBackward0>)
# tensor(2.3916, grad_fn=<NegBackward0>)
# tensor(2.4441, grad_fn=<NegBackward0>)
# tensor(2.7769, grad_fn=<NegBackward0>)
# tensor(2.8100, grad_fn=<NegBackward0>)
# tensor(2.4960, grad_fn=<NegBackward0>)
# tensor(2.2740, grad_fn=<NegBackward0>)
# tensor(2.7201, grad_fn=<NegBackward0>)
# tensor(2.0200, grad_fn=<NegBackward0>)
# tensor(2.6022, grad_fn=<NegBackward0>)
# tensor(2.3953, grad_fn=<NegBackward0>)
# tensor(2.3150, grad_fn=<NegBackward0>)
# tensor(2.4497, grad_fn=<NegBackward0>)
# tensor(2.6417, grad_fn=<NegBackward0>)
# tensor(2.7782, grad_fn=<NegBackward0>)
# tensor(2.2301, grad_fn=<NegBackward0>)
# tensor(2.3303, grad_fn=<NegBackward0>)
# tensor(2.4375, grad_fn=<NegBackward0>)
# tensor(2.7158, grad_fn=<NegBackward0>)
# tensor(2.6214, grad_fn=<NegBackward0>)
# tensor(2.6360, grad_fn=<NegBackward0>)
# tensor(2.4731, grad_fn=<NegBackward0>)
# tensor(2.7406, grad_fn=<NegBackward0>)
# tensor(2.4158, grad_fn=<NegBackward0>)
# tensor(2.2596, grad_fn=<NegBackward0>)
# tensor(2.5431, grad_fn=<NegBackward0>)
# tensor(2.5375, grad_fn=<NegBackward0>)
# tensor(2.3834, grad_fn=<NegBackward0>)
# tensor(2.5819, grad_fn=<NegBackward0>)
# tensor(2.5153, grad_fn=<NegBackward0>)
# tensor(2.4221, grad_fn=<NegBackward0>)
# tensor(2.2408, grad_fn=<NegBackward0>)
# tensor(2.3402, grad_fn=<NegBackward0>)
# tensor(2.5290, grad_fn=<NegBackward0>)
# tensor(2.4031, grad_fn=<NegBackward0>)
# tensor(2.1155, grad_fn=<NegBackward0>)
# tensor(2.5174, grad_fn=<NegBackward0>)
# tensor(2.5503, grad_fn=<NegBackward0>)
# tensor(2.1092, grad_fn=<NegBackward0>)
# tensor(2.6565, grad_fn=<NegBackward0>)
# tensor(2.4607, grad_fn=<NegBackward0>)
# tensor(2.0254, grad_fn=<NegBackward0>)
# tensor(2.5893, grad_fn=<NegBackward0>)
# tensor(2.4759, grad_fn=<NegBackward0>)
# tensor(2.3722, grad_fn=<NegBackward0>)
# tensor(2.3233, grad_fn=<NegBackward0>)
# tensor(2.5898, grad_fn=<NegBackward0>)
# tensor(2.3919, grad_fn=<NegBackward0>)
# tensor(2.4832, grad_fn=<NegBackward0>)
# tensor(2.4122, grad_fn=<NegBackward0>)
# tensor(2.5814, grad_fn=<NegBackward0>)
# tensor(2.5964, grad_fn=<NegBackward0>)
# tensor(2.5359, grad_fn=<NegBackward0>)
# tensor(2.6310, grad_fn=<NegBackward0>)
# tensor(2.6668, grad_fn=<NegBackward0>)
# tensor(2.6435, grad_fn=<NegBackward0>)
# tensor(2.5580, grad_fn=<NegBackward0>)
# tensor(2.5716, grad_fn=<NegBackward0>)
# tensor(2.6114, grad_fn=<NegBackward0>)
# tensor(2.4686, grad_fn=<NegBackward0>)
# tensor(2.5453, grad_fn=<NegBackward0>)
# tensor(2.3597, grad_fn=<NegBackward0>)
# tensor(2.5770, grad_fn=<NegBackward0>)
# tensor(2.4064, grad_fn=<NegBackward0>)
# tensor(2.2875, grad_fn=<NegBackward0>)
# tensor(3.2973, grad_fn=<NegBackward0>)
# tensor(2.5358, grad_fn=<NegBackward0>)
# tensor(2.5265, grad_fn=<NegBackward0>)
# tensor(2.3761, grad_fn=<NegBackward0>)
# tensor(2.5881, grad_fn=<NegBackward0>)
# tensor(2.5082, grad_fn=<NegBackward0>)
# tensor(2.5890, grad_fn=<NegBackward0>)
# tensor(2.4078, grad_fn=<NegBackward0>)
# tensor(2.5918, grad_fn=<NegBackward0>)
# tensor(2.3985, grad_fn=<NegBackward0>)
# tensor(2.2766, grad_fn=<NegBackward0>)
# tensor(2.1389, grad_fn=<NegBackward0>)
# tensor(2.2958, grad_fn=<NegBackward0>)
# tensor(2.1322, grad_fn=<NegBackward0>)
# tensor(2.6183, grad_fn=<NegBackward0>)
# tensor(2.2721, grad_fn=<NegBackward0>)
# tensor(2.3127, grad_fn=<NegBackward0>)
# tensor(2.2461, grad_fn=<NegBackward0>)
# tensor(2.3334, grad_fn=<NegBackward0>)
# tensor(2.3118, grad_fn=<NegBackward0>)
# tensor(2.4633, grad_fn=<NegBackward0>)
# tensor(2.5973, grad_fn=<NegBackward0>)
# tensor(2.4297, grad_fn=<NegBackward0>)
# tensor(2.2652, grad_fn=<NegBackward0>)
# tensor(2.4763, grad_fn=<NegBackward0>)
# tensor(2.4273, grad_fn=<NegBackward0>)
# tensor(2.5575, grad_fn=<NegBackward0>)
# tensor(2.4403, grad_fn=<NegBackward0>)
# tensor(2.2277, grad_fn=<NegBackward0>)
# tensor(2.5724, grad_fn=<NegBackward0>)
# tensor(2.5632, grad_fn=<NegBackward0>)
# tensor(2.2479, grad_fn=<NegBackward0>)
# tensor(2.3661, grad_fn=<NegBackward0>)
# tensor(2.5990, grad_fn=<NegBackward0>)
# tensor(2.2820, grad_fn=<NegBackward0>)
# tensor(2.4942, grad_fn=<NegBackward0>)
# tensor(2.1991, grad_fn=<NegBackward0>)
# tensor(2.2629, grad_fn=<NegBackward0>)
# tensor(2.4151, grad_fn=<NegBackward0>)
# tensor(2.1553, grad_fn=<NegBackward0>)
# tensor(2.4375, grad_fn=<NegBackward0>)
# tensor(2.3187, grad_fn=<NegBackward0>)
# tensor(2.6512, grad_fn=<NegBackward0>)
# tensor(2.5020, grad_fn=<NegBackward0>)
# tensor(2.5860, grad_fn=<NegBackward0>)
# tensor(2.4861, grad_fn=<NegBackward0>)
# tensor(2.5554, grad_fn=<NegBackward0>)
# tensor(2.7032, grad_fn=<NegBackward0>)
# tensor(2.4885, grad_fn=<NegBackward0>)
# tensor(2.5120, grad_fn=<NegBackward0>)
# tensor(2.2514, grad_fn=<NegBackward0>)
# tensor(2.3821, grad_fn=<NegBackward0>)
# tensor(2.4593, grad_fn=<NegBackward0>)
# tensor(2.4210, grad_fn=<NegBackward0>)
# tensor(2.2909, grad_fn=<NegBackward0>)
# tensor(2.4024, grad_fn=<NegBackward0>)
# tensor(2.2209, grad_fn=<NegBackward0>)
# tensor(2.6099, grad_fn=<NegBackward0>)
# tensor(2.3894, grad_fn=<NegBackward0>)
# tensor(2.2733, grad_fn=<NegBackward0>)
# tensor(2.6694, grad_fn=<NegBackward0>)
# tensor(2.7173, grad_fn=<NegBackward0>)
# tensor(2.4856, grad_fn=<NegBackward0>)
# tensor(2.4858, grad_fn=<NegBackward0>)
# tensor(2.3360, grad_fn=<NegBackward0>)
# tensor(2.2917, grad_fn=<NegBackward0>)
# tensor(2.3559, grad_fn=<NegBackward0>)
# tensor(2.4576, grad_fn=<NegBackward0>)
# tensor(2.1074, grad_fn=<NegBackward0>)
# tensor(2.2731, grad_fn=<NegBackward0>)
# tensor(2.4193, grad_fn=<NegBackward0>)
# tensor(2.4350, grad_fn=<NegBackward0>)
# tensor(2.5757, grad_fn=<NegBackward0>)
# tensor(2.5691, grad_fn=<NegBackward0>)
# tensor(2.6249, grad_fn=<NegBackward0>)
# tensor(2.4117, grad_fn=<NegBackward0>)
# tensor(2.5042, grad_fn=<NegBackward0>)
# tensor(2.5146, grad_fn=<NegBackward0>)
# tensor(2.6283, grad_fn=<NegBackward0>)
# tensor(2.3654, grad_fn=<NegBackward0>)
# tensor(2.5731, grad_fn=<NegBackward0>)
# tensor(2.6026, grad_fn=<NegBackward0>)
# tensor(2.4377, grad_fn=<NegBackward0>)
# tensor(2.5304, grad_fn=<NegBackward0>)
# tensor(2.1963, grad_fn=<NegBackward0>)
# tensor(2.8949, grad_fn=<NegBackward0>)
# tensor(2.4831, grad_fn=<NegBackward0>)
# tensor(2.4774, grad_fn=<NegBackward0>)
# tensor(2.2436, grad_fn=<NegBackward0>)
# tensor(2.2869, grad_fn=<NegBackward0>)
# tensor(2.4041, grad_fn=<NegBackward0>)
# tensor(2.6248, grad_fn=<NegBackward0>)
# tensor(2.5617, grad_fn=<NegBackward0>)
# tensor(2.6881, grad_fn=<NegBackward0>)
# tensor(2.2823, grad_fn=<NegBackward0>)
# tensor(2.7785, grad_fn=<NegBackward0>)
# tensor(2.4038, grad_fn=<NegBackward0>)
# tensor(2.5478, grad_fn=<NegBackward0>)
# tensor(2.4706, grad_fn=<NegBackward0>)
# tensor(2.6690, grad_fn=<NegBackward0>)
# tensor(2.6013, grad_fn=<NegBackward0>)
# tensor(2.8017, grad_fn=<NegBackward0>)
# tensor(2.3212, grad_fn=<NegBackward0>)
# tensor(2.2723, grad_fn=<NegBackward0>)
# tensor(2.3965, grad_fn=<NegBackward0>)
# tensor(2.8103, grad_fn=<NegBackward0>)
# tensor(2.7550, grad_fn=<NegBackward0>)
# tensor(2.4737, grad_fn=<NegBackward0>)
# tensor(2.5952, grad_fn=<NegBackward0>)
# tensor(2.6250, grad_fn=<NegBackward0>)
# tensor(2.2439, grad_fn=<NegBackward0>)
# tensor(2.5627, grad_fn=<NegBackward0>)
# tensor(2.3475, grad_fn=<NegBackward0>)
# tensor(2.4175, grad_fn=<NegBackward0>)
# tensor(3.0548, grad_fn=<NegBackward0>)
# tensor(2.1672, grad_fn=<NegBackward0>)
# tensor(2.6403, grad_fn=<NegBackward0>)
# tensor(2.1977, grad_fn=<NegBackward0>)
# tensor(2.5820, grad_fn=<NegBackward0>)
# tensor(2.3179, grad_fn=<NegBackward0>)
# tensor(2.3287, grad_fn=<NegBackward0>)
# tensor(2.5485, grad_fn=<NegBackward0>)
# tensor(2.4306, grad_fn=<NegBackward0>)
# tensor(2.7293, grad_fn=<NegBackward0>)
# tensor(2.4461, grad_fn=<NegBackward0>)
# tensor(2.6045, grad_fn=<NegBackward0>)
# tensor(2.4452, grad_fn=<NegBackward0>)
# tensor(2.0915, grad_fn=<NegBackward0>)
# tensor(2.6478, grad_fn=<NegBackward0>)
# tensor(2.1890, grad_fn=<NegBackward0>)
# tensor(2.7067, grad_fn=<NegBackward0>)
# tensor(2.6111, grad_fn=<NegBackward0>)
# tensor(2.6023, grad_fn=<NegBackward0>)
# tensor(2.4773, grad_fn=<NegBackward0>)
# tensor(2.4521, grad_fn=<NegBackward0>)
# tensor(2.1174, grad_fn=<NegBackward0>)
# tensor(2.3079, grad_fn=<NegBackward0>)
# tensor(2.9291, grad_fn=<NegBackward0>)
# tensor(2.5980, grad_fn=<NegBackward0>)
# tensor(2.3259, grad_fn=<NegBackward0>)
# tensor(2.5395, grad_fn=<NegBackward0>)
# tensor(2.5736, grad_fn=<NegBackward0>)
# tensor(2.3533, grad_fn=<NegBackward0>)
# tensor(2.2647, grad_fn=<NegBackward0>)
# tensor(2.5055, grad_fn=<NegBackward0>)
# tensor(2.2557, grad_fn=<NegBackward0>)
# tensor(2.3696, grad_fn=<NegBackward0>)
# tensor(2.0284, grad_fn=<NegBackward0>)
# tensor(2.5670, grad_fn=<NegBackward0>)
# tensor(2.5574, grad_fn=<NegBackward0>)
# tensor(2.1743, grad_fn=<NegBackward0>)
# tensor(2.3552, grad_fn=<NegBackward0>)
# tensor(2.6866, grad_fn=<NegBackward0>)
# tensor(2.8710, grad_fn=<NegBackward0>)
# tensor(2.6762, grad_fn=<NegBackward0>)
# tensor(2.4638, grad_fn=<NegBackward0>)
# tensor(2.6802, grad_fn=<NegBackward0>)
# tensor(2.7727, grad_fn=<NegBackward0>)
# tensor(2.6680, grad_fn=<NegBackward0>)
# tensor(2.1868, grad_fn=<NegBackward0>)
# tensor(2.3040, grad_fn=<NegBackward0>)
# tensor(2.4263, grad_fn=<NegBackward0>)
# tensor(2.6227, grad_fn=<NegBackward0>)
# tensor(2.7512, grad_fn=<NegBackward0>)
# tensor(2.5280, grad_fn=<NegBackward0>)
# tensor(2.5779, grad_fn=<NegBackward0>)
# tensor(2.8089, grad_fn=<NegBackward0>)
# tensor(2.4678, grad_fn=<NegBackward0>)
# tensor(2.3510, grad_fn=<NegBackward0>)
# tensor(2.4113, grad_fn=<NegBackward0>)
# tensor(2.4501, grad_fn=<NegBackward0>)
# tensor(2.5134, grad_fn=<NegBackward0>)
# tensor(2.5850, grad_fn=<NegBackward0>)
# tensor(1.9976, grad_fn=<NegBackward0>)
# tensor(2.3050, grad_fn=<NegBackward0>)
# tensor(2.6219, grad_fn=<NegBackward0>)
# tensor(2.2778, grad_fn=<NegBackward0>)
# tensor(2.3188, grad_fn=<NegBackward0>)
# tensor(2.2428, grad_fn=<NegBackward0>)
# tensor(2.3683, grad_fn=<NegBackward0>)
# tensor(2.5686, grad_fn=<NegBackward0>)
# tensor(2.7471, grad_fn=<NegBackward0>)
# tensor(2.1628, grad_fn=<NegBackward0>)
# tensor(2.6997, grad_fn=<NegBackward0>)
# tensor(2.3833, grad_fn=<NegBackward0>)
# tensor(2.3607, grad_fn=<NegBackward0>)
# tensor(2.3210, grad_fn=<NegBackward0>)
# tensor(2.6096, grad_fn=<NegBackward0>)
# tensor(2.4914, grad_fn=<NegBackward0>)
# tensor(2.3889, grad_fn=<NegBackward0>)
# tensor(2.1138, grad_fn=<NegBackward0>)
# tensor(2.3036, grad_fn=<NegBackward0>)
# tensor(2.2789, grad_fn=<NegBackward0>)
# tensor(2.3384, grad_fn=<NegBackward0>)
# tensor(2.6011, grad_fn=<NegBackward0>)
# tensor(2.6067, grad_fn=<NegBackward0>)
# tensor(2.4715, grad_fn=<NegBackward0>)
# tensor(2.6614, grad_fn=<NegBackward0>)
# tensor(2.3114, grad_fn=<NegBackward0>)
# tensor(2.4382, grad_fn=<NegBackward0>)
# tensor(2.4175, grad_fn=<NegBackward0>)
# tensor(2.3690, grad_fn=<NegBackward0>)
# tensor(2.4488, grad_fn=<NegBackward0>)
# tensor(2.9990, grad_fn=<NegBackward0>)
# tensor(2.5198, grad_fn=<NegBackward0>)
# tensor(2.3960, grad_fn=<NegBackward0>)
# tensor(2.3157, grad_fn=<NegBackward0>)
# tensor(2.5330, grad_fn=<NegBackward0>)
# tensor(2.4534, grad_fn=<NegBackward0>)
# tensor(2.4293, grad_fn=<NegBackward0>)
# tensor(2.4610, grad_fn=<NegBackward0>)
# tensor(2.6145, grad_fn=<NegBackward0>)
# tensor(2.3732, grad_fn=<NegBackward0>)
# tensor(2.3612, grad_fn=<NegBackward0>)
# tensor(2.5299, grad_fn=<NegBackward0>)
# tensor(2.3725, grad_fn=<NegBackward0>)
# tensor(2.3787, grad_fn=<NegBackward0>)
# tensor(2.5850, grad_fn=<NegBackward0>)
# tensor(2.4837, grad_fn=<NegBackward0>)
# tensor(2.5021, grad_fn=<NegBackward0>)
# tensor(2.7256, grad_fn=<NegBackward0>)
# tensor(2.5043, grad_fn=<NegBackward0>)
# tensor(2.3229, grad_fn=<NegBackward0>)
# tensor(2.5422, grad_fn=<NegBackward0>)
# tensor(2.3267, grad_fn=<NegBackward0>)
# tensor(3.1437, grad_fn=<NegBackward0>)
# tensor(2.3334, grad_fn=<NegBackward0>)
# tensor(2.2855, grad_fn=<NegBackward0>)
# tensor(2.5606, grad_fn=<NegBackward0>)
# tensor(2.5545, grad_fn=<NegBackward0>)
# tensor(2.7942, grad_fn=<NegBackward0>)
# tensor(2.3182, grad_fn=<NegBackward0>)
# tensor(2.4425, grad_fn=<NegBackward0>)
# tensor(2.4141, grad_fn=<NegBackward0>)
# tensor(2.4882, grad_fn=<NegBackward0>)
# tensor(2.3301, grad_fn=<NegBackward0>)
# tensor(2.9181, grad_fn=<NegBackward0>)
# tensor(2.3513, grad_fn=<NegBackward0>)
# tensor(2.1198, grad_fn=<NegBackward0>)
# tensor(2.6484, grad_fn=<NegBackward0>)
# tensor(2.6154, grad_fn=<NegBackward0>)
# tensor(2.3297, grad_fn=<NegBackward0>)
# tensor(2.8032, grad_fn=<NegBackward0>)
# tensor(2.5711, grad_fn=<NegBackward0>)
# tensor(2.3722, grad_fn=<NegBackward0>)
# tensor(2.1930, grad_fn=<NegBackward0>)
# tensor(2.5945, grad_fn=<NegBackward0>)
# tensor(2.4048, grad_fn=<NegBackward0>)
# tensor(2.4005, grad_fn=<NegBackward0>)
# tensor(2.8126, grad_fn=<NegBackward0>)
# tensor(2.1835, grad_fn=<NegBackward0>)
# tensor(2.4951, grad_fn=<NegBackward0>)
# tensor(2.2892, grad_fn=<NegBackward0>)
# tensor(2.5074, grad_fn=<NegBackward0>)
# tensor(2.5004, grad_fn=<NegBackward0>)
# tensor(2.4206, grad_fn=<NegBackward0>)
# tensor(2.4445, grad_fn=<NegBackward0>)
# tensor(2.6126, grad_fn=<NegBackward0>)
# tensor(2.5518, grad_fn=<NegBackward0>)
# tensor(2.9760, grad_fn=<NegBackward0>)
# tensor(2.1804, grad_fn=<NegBackward0>)
# tensor(2.6455, grad_fn=<NegBackward0>)
# tensor(2.6003, grad_fn=<NegBackward0>)
# tensor(2.5043, grad_fn=<NegBackward0>)
# tensor(2.2860, grad_fn=<NegBackward0>)
# tensor(2.4837, grad_fn=<NegBackward0>)
# tensor(2.2245, grad_fn=<NegBackward0>)
# tensor(2.4079, grad_fn=<NegBackward0>)
# tensor(2.1622, grad_fn=<NegBackward0>)
# tensor(2.4559, grad_fn=<NegBackward0>)
# tensor(2.3641, grad_fn=<NegBackward0>)
# tensor(2.7384, grad_fn=<NegBackward0>)
# tensor(2.3697, grad_fn=<NegBackward0>)
# tensor(2.2505, grad_fn=<NegBackward0>)
# tensor(2.4447, grad_fn=<NegBackward0>)
# tensor(2.3523, grad_fn=<NegBackward0>)
# tensor(2.5600, grad_fn=<NegBackward0>)
# tensor(2.7834, grad_fn=<NegBackward0>)
# tensor(2.5753, grad_fn=<NegBackward0>)
# tensor(2.4110, grad_fn=<NegBackward0>)
# tensor(2.3149, grad_fn=<NegBackward0>)
# tensor(2.3852, grad_fn=<NegBackward0>)
# tensor(2.5693, grad_fn=<NegBackward0>)
# tensor(2.2852, grad_fn=<NegBackward0>)
# tensor(2.3564, grad_fn=<NegBackward0>)
# tensor(2.2132, grad_fn=<NegBackward0>)
# tensor(2.6330, grad_fn=<NegBackward0>)
# tensor(2.6935, grad_fn=<NegBackward0>)
# tensor(2.1481, grad_fn=<NegBackward0>)
# tensor(2.4795, grad_fn=<NegBackward0>)
# tensor(2.5050, grad_fn=<NegBackward0>)
# tensor(2.6307, grad_fn=<NegBackward0>)
# tensor(2.5791, grad_fn=<NegBackward0>)
# tensor(2.6655, grad_fn=<NegBackward0>)
# tensor(2.2002, grad_fn=<NegBackward0>)
# tensor(2.5360, grad_fn=<NegBackward0>)
# tensor(2.4048, grad_fn=<NegBackward0>)
# tensor(2.6078, grad_fn=<NegBackward0>)
# tensor(2.3747, grad_fn=<NegBackward0>)
# tensor(2.5939, grad_fn=<NegBackward0>)
# tensor(2.2893, grad_fn=<NegBackward0>)
# tensor(2.5381, grad_fn=<NegBackward0>)
# tensor(2.3547, grad_fn=<NegBackward0>)
# tensor(2.2983, grad_fn=<NegBackward0>)
# tensor(2.2212, grad_fn=<NegBackward0>)
# tensor(2.4307, grad_fn=<NegBackward0>)
# tensor(2.8920, grad_fn=<NegBackward0>)
# tensor(2.3986, grad_fn=<NegBackward0>)
# tensor(2.3811, grad_fn=<NegBackward0>)
# tensor(2.1799, grad_fn=<NegBackward0>)
# tensor(2.3462, grad_fn=<NegBackward0>)
# tensor(2.3186, grad_fn=<NegBackward0>)
# tensor(2.2230, grad_fn=<NegBackward0>)
# tensor(2.8370, grad_fn=<NegBackward0>)
# tensor(2.3199, grad_fn=<NegBackward0>)
# tensor(3.1245, grad_fn=<NegBackward0>)
# tensor(2.5563, grad_fn=<NegBackward0>)
# tensor(2.2702, grad_fn=<NegBackward0>)
# tensor(2.3092, grad_fn=<NegBackward0>)
# tensor(2.1927, grad_fn=<NegBackward0>)
# tensor(2.2823, grad_fn=<NegBackward0>)
# tensor(2.3437, grad_fn=<NegBackward0>)
# tensor(2.3911, grad_fn=<NegBackward0>)
# tensor(2.3970, grad_fn=<NegBackward0>)
# tensor(2.5582, grad_fn=<NegBackward0>)
# tensor(2.7941, grad_fn=<NegBackward0>)
# tensor(2.6317, grad_fn=<NegBackward0>)
# tensor(2.4259, grad_fn=<NegBackward0>)
# tensor(2.5128, grad_fn=<NegBackward0>)
# tensor(2.3938, grad_fn=<NegBackward0>)
# tensor(2.4848, grad_fn=<NegBackward0>)
# tensor(2.6781, grad_fn=<NegBackward0>)
# tensor(2.5840, grad_fn=<NegBackward0>)
# tensor(2.6162, grad_fn=<NegBackward0>)
# tensor(2.6839, grad_fn=<NegBackward0>)
# tensor(2.4312, grad_fn=<NegBackward0>)
# tensor(2.5270, grad_fn=<NegBackward0>)
# tensor(2.5108, grad_fn=<NegBackward0>)
# tensor(2.6656, grad_fn=<NegBackward0>)
# tensor(2.4913, grad_fn=<NegBackward0>)
# tensor(2.5647, grad_fn=<NegBackward0>)
# tensor(2.3811, grad_fn=<NegBackward0>)
# tensor(2.5012, grad_fn=<NegBackward0>)
# tensor(2.7768, grad_fn=<NegBackward0>)
# tensor(2.3553, grad_fn=<NegBackward0>)
# tensor(2.3508, grad_fn=<NegBackward0>)
# tensor(2.4690, grad_fn=<NegBackward0>)
# tensor(2.9420, grad_fn=<NegBackward0>)
# tensor(2.3641, grad_fn=<NegBackward0>)
# tensor(2.2109, grad_fn=<NegBackward0>)
# tensor(2.5195, grad_fn=<NegBackward0>)
# tensor(2.2970, grad_fn=<NegBackward0>)
# tensor(2.4045, grad_fn=<NegBackward0>)
# tensor(2.4769, grad_fn=<NegBackward0>)
# tensor(2.1869, grad_fn=<NegBackward0>)
# tensor(2.6042, grad_fn=<NegBackward0>)
# tensor(2.5529, grad_fn=<NegBackward0>)
# tensor(2.2827, grad_fn=<NegBackward0>)
# tensor(2.6265, grad_fn=<NegBackward0>)
# tensor(2.3697, grad_fn=<NegBackward0>)
# tensor(2.6229, grad_fn=<NegBackward0>)
# tensor(2.4055, grad_fn=<NegBackward0>)
# tensor(2.4470, grad_fn=<NegBackward0>)
# tensor(2.5709, grad_fn=<NegBackward0>)
# tensor(2.5550, grad_fn=<NegBackward0>)
# tensor(2.4409, grad_fn=<NegBackward0>)
# tensor(2.3592, grad_fn=<NegBackward0>)
# tensor(2.0703, grad_fn=<NegBackward0>)
# tensor(2.0738, grad_fn=<NegBackward0>)
# tensor(2.4339, grad_fn=<NegBackward0>)
# tensor(2.7509, grad_fn=<NegBackward0>)
# tensor(2.5192, grad_fn=<NegBackward0>)
# tensor(2.2990, grad_fn=<NegBackward0>)
# tensor(2.1774, grad_fn=<NegBackward0>)
# tensor(2.3893, grad_fn=<NegBackward0>)
# tensor(2.4397, grad_fn=<NegBackward0>)
# tensor(2.7369, grad_fn=<NegBackward0>)
# tensor(2.4551, grad_fn=<NegBackward0>)
# tensor(2.6502, grad_fn=<NegBackward0>)
# tensor(2.4301, grad_fn=<NegBackward0>)
# tensor(2.4676, grad_fn=<NegBackward0>)
# tensor(2.6651, grad_fn=<NegBackward0>)
# tensor(2.4776, grad_fn=<NegBackward0>)
# tensor(2.5383, grad_fn=<NegBackward0>)
# tensor(2.7529, grad_fn=<NegBackward0>)
# tensor(2.4969, grad_fn=<NegBackward0>)
# tensor(2.6428, grad_fn=<NegBackward0>)
# tensor(2.5956, grad_fn=<NegBackward0>)
# tensor(2.3115, grad_fn=<NegBackward0>)
# tensor(2.8836, grad_fn=<NegBackward0>)
# tensor(2.6086, grad_fn=<NegBackward0>)
# tensor(2.4680, grad_fn=<NegBackward0>)
# tensor(2.8986, grad_fn=<NegBackward0>)
# tensor(2.3199, grad_fn=<NegBackward0>)
# tensor(2.4476, grad_fn=<NegBackward0>)
# tensor(2.7086, grad_fn=<NegBackward0>)
# tensor(2.4477, grad_fn=<NegBackward0>)
# tensor(2.5640, grad_fn=<NegBackward0>)
# tensor(2.4015, grad_fn=<NegBackward0>)
# tensor(2.6900, grad_fn=<NegBackward0>)
# tensor(2.4126, grad_fn=<NegBackward0>)
# tensor(2.4762, grad_fn=<NegBackward0>)
# tensor(2.4190, grad_fn=<NegBackward0>)
# tensor(2.7893, grad_fn=<NegBackward0>)
# tensor(2.5817, grad_fn=<NegBackward0>)
# tensor(2.3951, grad_fn=<NegBackward0>)
# tensor(2.4909, grad_fn=<NegBackward0>)
# tensor(2.3547, grad_fn=<NegBackward0>)
# tensor(2.4817, grad_fn=<NegBackward0>)
# tensor(2.6052, grad_fn=<NegBackward0>)
# tensor(2.2683, grad_fn=<NegBackward0>)
# tensor(2.5615, grad_fn=<NegBackward0>)
# tensor(2.3855, grad_fn=<NegBackward0>)
# tensor(2.5781, grad_fn=<NegBackward0>)
# tensor(2.1986, grad_fn=<NegBackward0>)
# tensor(2.7999, grad_fn=<NegBackward0>)
# tensor(2.5349, grad_fn=<NegBackward0>)
# tensor(2.4683, grad_fn=<NegBackward0>)
# tensor(2.4656, grad_fn=<NegBackward0>)
# tensor(2.0930, grad_fn=<NegBackward0>)
# tensor(2.4481, grad_fn=<NegBackward0>)
# tensor(2.3797, grad_fn=<NegBackward0>)
# tensor(2.5933, grad_fn=<NegBackward0>)
# tensor(2.5743, grad_fn=<NegBackward0>)
# tensor(2.7404, grad_fn=<NegBackward0>)
# tensor(2.7277, grad_fn=<NegBackward0>)
# tensor(2.9553, grad_fn=<NegBackward0>)
# tensor(2.4668, grad_fn=<NegBackward0>)
# tensor(2.9049, grad_fn=<NegBackward0>)
# tensor(2.5680, grad_fn=<NegBackward0>)
# tensor(2.4539, grad_fn=<NegBackward0>)
# tensor(2.6477, grad_fn=<NegBackward0>)
# tensor(2.2902, grad_fn=<NegBackward0>)
# tensor(2.4580, grad_fn=<NegBackward0>)
# tensor(2.6009, grad_fn=<NegBackward0>)
# tensor(2.4819, grad_fn=<NegBackward0>)
# tensor(2.7489, grad_fn=<NegBackward0>)
# tensor(2.4024, grad_fn=<NegBackward0>)
# tensor(2.0892, grad_fn=<NegBackward0>)
# tensor(2.5647, grad_fn=<NegBackward0>)
# tensor(2.4634, grad_fn=<NegBackward0>)
# tensor(2.2215, grad_fn=<NegBackward0>)
# tensor(2.4295, grad_fn=<NegBackward0>)
# tensor(2.4448, grad_fn=<NegBackward0>)
# tensor(2.0408, grad_fn=<NegBackward0>)
# tensor(2.5707, grad_fn=<NegBackward0>)
# tensor(2.5244, grad_fn=<NegBackward0>)
# tensor(2.5658, grad_fn=<NegBackward0>)
# tensor(2.7507, grad_fn=<NegBackward0>)
# tensor(2.3103, grad_fn=<NegBackward0>)
# tensor(2.4837, grad_fn=<NegBackward0>)
# tensor(2.4223, grad_fn=<NegBackward0>)
# tensor(2.6297, grad_fn=<NegBackward0>)
# tensor(2.3728, grad_fn=<NegBackward0>)
# tensor(2.4822, grad_fn=<NegBackward0>)
# tensor(2.4205, grad_fn=<NegBackward0>)
# tensor(2.6413, grad_fn=<NegBackward0>)
# tensor(2.4773, grad_fn=<NegBackward0>)
# tensor(2.9137, grad_fn=<NegBackward0>)
# tensor(2.2130, grad_fn=<NegBackward0>)
# tensor(2.2661, grad_fn=<NegBackward0>)
# tensor(2.3242, grad_fn=<NegBackward0>)
# tensor(2.8024, grad_fn=<NegBackward0>)
# tensor(2.5966, grad_fn=<NegBackward0>)
# tensor(2.7140, grad_fn=<NegBackward0>)
# tensor(2.8618, grad_fn=<NegBackward0>)
# tensor(2.3029, grad_fn=<NegBackward0>)
# tensor(2.5166, grad_fn=<NegBackward0>)
# tensor(2.3977, grad_fn=<NegBackward0>)
# tensor(2.8874, grad_fn=<NegBackward0>)
# tensor(2.5889, grad_fn=<NegBackward0>)
# tensor(2.2704, grad_fn=<NegBackward0>)
# tensor(2.4482, grad_fn=<NegBackward0>)
# tensor(2.4008, grad_fn=<NegBackward0>)
# tensor(2.5942, grad_fn=<NegBackward0>)
# tensor(2.3951, grad_fn=<NegBackward0>)
# tensor(2.4975, grad_fn=<NegBackward0>)
# tensor(2.3501, grad_fn=<NegBackward0>)
# tensor(2.4041, grad_fn=<NegBackward0>)
# tensor(2.5168, grad_fn=<NegBackward0>)
# tensor(2.6385, grad_fn=<NegBackward0>)
# tensor(1.9213, grad_fn=<NegBackward0>)
# tensor(2.9712, grad_fn=<NegBackward0>)
# tensor(2.9277, grad_fn=<NegBackward0>)
# tensor(2.4087, grad_fn=<NegBackward0>)
# tensor(2.5104, grad_fn=<NegBackward0>)
# tensor(2.4197, grad_fn=<NegBackward0>)
# tensor(2.2340, grad_fn=<NegBackward0>)
# tensor(2.3295, grad_fn=<NegBackward0>)
# tensor(2.3759, grad_fn=<NegBackward0>)
# tensor(2.7799, grad_fn=<NegBackward0>)
# tensor(2.5442, grad_fn=<NegBackward0>)
# tensor(2.1373, grad_fn=<NegBackward0>)
# tensor(2.5587, grad_fn=<NegBackward0>)
# tensor(2.5903, grad_fn=<NegBackward0>)
# tensor(2.3810, grad_fn=<NegBackward0>)
# tensor(2.3355, grad_fn=<NegBackward0>)
# tensor(2.4949, grad_fn=<NegBackward0>)
# tensor(2.6536, grad_fn=<NegBackward0>)
# tensor(2.5052, grad_fn=<NegBackward0>)
# tensor(2.7026, grad_fn=<NegBackward0>)
# tensor(2.7383, grad_fn=<NegBackward0>)
# tensor(2.5482, grad_fn=<NegBackward0>)
# tensor(2.5269, grad_fn=<NegBackward0>)
# tensor(2.3995, grad_fn=<NegBackward0>)
# tensor(2.6970, grad_fn=<NegBackward0>)
# tensor(2.7952, grad_fn=<NegBackward0>)
# tensor(2.4223, grad_fn=<NegBackward0>)
# tensor(2.5381, grad_fn=<NegBackward0>)
# tensor(2.7015, grad_fn=<NegBackward0>)
# tensor(2.5554, grad_fn=<NegBackward0>)
# tensor(2.2581, grad_fn=<NegBackward0>)
# tensor(2.4697, grad_fn=<NegBackward0>)
# tensor(2.5238, grad_fn=<NegBackward0>)
# tensor(2.5726, grad_fn=<NegBackward0>)
# tensor(2.5319, grad_fn=<NegBackward0>)
# tensor(2.5100, grad_fn=<NegBackward0>)
# tensor(2.4010, grad_fn=<NegBackward0>)
# tensor(2.8483, grad_fn=<NegBackward0>)
# tensor(2.3505, grad_fn=<NegBackward0>)
# tensor(2.1458, grad_fn=<NegBackward0>)
# tensor(2.4367, grad_fn=<NegBackward0>)
# tensor(2.6459, grad_fn=<NegBackward0>)
# tensor(2.8774, grad_fn=<NegBackward0>)
# tensor(2.2449, grad_fn=<NegBackward0>)
# tensor(2.5602, grad_fn=<NegBackward0>)
# tensor(2.2345, grad_fn=<NegBackward0>)
# tensor(2.1433, grad_fn=<NegBackward0>)
# tensor(2.6158, grad_fn=<NegBackward0>)
# tensor(2.4369, grad_fn=<NegBackward0>)
# tensor(2.3588, grad_fn=<NegBackward0>)
# tensor(2.5634, grad_fn=<NegBackward0>)
# tensor(2.1011, grad_fn=<NegBackward0>)
# tensor(2.5884, grad_fn=<NegBackward0>)
# tensor(2.3983, grad_fn=<NegBackward0>)
# tensor(2.1416, grad_fn=<NegBackward0>)
# tensor(2.4676, grad_fn=<NegBackward0>)
# tensor(2.8744, grad_fn=<NegBackward0>)
# tensor(2.3284, grad_fn=<NegBackward0>)
# tensor(2.5490, grad_fn=<NegBackward0>)
# tensor(2.2972, grad_fn=<NegBackward0>)
# tensor(2.5418, grad_fn=<NegBackward0>)
# tensor(2.4302, grad_fn=<NegBackward0>)
# tensor(2.3641, grad_fn=<NegBackward0>)
# tensor(2.6713, grad_fn=<NegBackward0>)
# tensor(2.4030, grad_fn=<NegBackward0>)
# tensor(2.5433, grad_fn=<NegBackward0>)
# tensor(2.9602, grad_fn=<NegBackward0>)
# tensor(2.3627, grad_fn=<NegBackward0>)
# tensor(2.3830, grad_fn=<NegBackward0>)
# tensor(2.3288, grad_fn=<NegBackward0>)
# tensor(2.5781, grad_fn=<NegBackward0>)
# tensor(2.8119, grad_fn=<NegBackward0>)
# tensor(2.5901, grad_fn=<NegBackward0>)
# tensor(2.5589, grad_fn=<NegBackward0>)
# tensor(2.3798, grad_fn=<NegBackward0>)
# tensor(2.3106, grad_fn=<NegBackward0>)
# tensor(2.1278, grad_fn=<NegBackward0>)
# tensor(2.5256, grad_fn=<NegBackward0>)
# tensor(2.3632, grad_fn=<NegBackward0>)
# tensor(2.6471, grad_fn=<NegBackward0>)
# tensor(2.4833, grad_fn=<NegBackward0>)
# tensor(2.4532, grad_fn=<NegBackward0>)
# tensor(2.1365, grad_fn=<NegBackward0>)
# tensor(2.6944, grad_fn=<NegBackward0>)
# tensor(2.4426, grad_fn=<NegBackward0>)

# %%
xs[torch.randint(0, xs.shape[0], (32,))]
# Out:
# tensor([[ 5, 12, 12],
#         [ 4, 18,  9],
#         [ 0,  0, 19],
#         [ 0, 11,  1],
#         [14, 20, 15],
#         [ 0,  5, 14],
#         [ 5, 12, 12],
#         [ 0,  3,  1],
#         [20,  1, 12],
#         [13,  9, 18],
#         [ 9, 12, 12],
#         [ 0,  0,  0],
#         [ 1, 26, 25],
#         [15, 18,  7],
#         [12,  9,  4],
#         [ 0,  0,  1],
#         [ 5, 14,  1],
#         [14,  4,  1],
#         [20, 21,  3],
#         [10,  8,  1],
#         [ 1,  8, 12],
#         [ 0,  0,  1],
#         [ 0,  1, 12],
#         [ 0,  0,  0],
#         [ 0,  0,  9],
#         [ 0,  0,  4],
#         [ 0,  0,  0],
#         [ 0,  1, 14],
#         [ 5, 12, 25],
#         [21,  2, 18],
#         [25, 12,  5],
#         [10,  1,  8]])

# %%
########## NEW ##################

# %%
# Hyperparameters
c_map_dim = 3   # Dimension of map
c_num = 5
l1_size = 300   # Number of neurons in the 1st layer
batch_size = 50

# %%
def build_dataset(words):
    xs = []
    ys = []
    for w in words:
        s = c_num * "."
        for chr in (w + "."):
            xs.append([stoi[ch] for ch in s])
            ys.append(stoi[chr])
            #print(f"{s} : {chr}")
            s = s[1:] + chr
    xs = torch.tensor(xs)
    ys = torch.tensor(ys)
    return xs, ys

import random
random.seed(42)
random.shuffle(words)
n1 = int(0.8 * len(words))
n2 = int(0.9 * len(words))
Xtr, Ytr = build_dataset(words[:n1])
Xdev, Ydev = build_dataset(words[n1:n2])
Xte, Yte = build_dataset(words[n2:])

# %%
# Initialization of parameters
g = torch.Generator().manual_seed(2147483647)   # For reproducibility
C = torch.randn((27, c_map_dim), generator=g)   # Character map generation

# Layer generation
W1 = torch.randn((l1_size, c_map_dim * c_num), generator=g)   #1st layer
b1 = torch.randn((l1_size, 1), generator=g)
W2 = torch.randn((27, l1_size), generator=g)   # Final layer
b2 = torch.randn((27, 1), generator=g)

parameters = [C, W1, b1, W2, b2]

for p in parameters:
    p.requires_grad = True

# %%
lri = []
lossi = []
stepi = []

for i in range(200000):

    ix = torch.randint(0, Xtr.shape[0], (batch_size,))
    batch = Xtr[ix]
    yr = Ytr[ix]

    b = C[batch].view(-1,c_num * c_map_dim)
    a = torch.transpose(b, 0, 1)

    # 1st layer neurons
    l1 = torch.tanh(W1 @ a + b1)

    # last layer
    logits = (W2 @ l1 + b2)
    logits = torch.transpose(logits, 0, 1)

    loss = F.cross_entropy(logits, yr)

    for p in parameters:
         p.grad = None

    loss.backward()

    if i < 100000:
        h = 0.1
    else:
        h = 0.01
    # h = lrs[i]

    for p in parameters:
        p.data += - h * p.grad

    # Stat tracking
    # lri.append(lre[i])
    lossi.append(loss.item())
    stepi.append(i)

print(loss.item())
# Out:
# 2.2156167030334473

# %%
plt.plot(stepi, lossi)

# %%
b = C[Xdev].view(-1,c_num * c_map_dim)
a = torch.transpose(b, 0, 1)

    # 1st layer neurons
l1 = torch.tanh(W1 @ a + b1)
    # last layer
logits = torch.transpose((W2 @ l1 + b2), 0, 1)

loss = F.cross_entropy(logits, Ydev)
print(loss)
# Out:
# tensor(2.1958, grad_fn=<NllLossBackward0>)

# %%
for i in range(10):
    out = []
    s = [0] * c_num
    while True:
        b = C[s].view(-1,c_map_dim * c_num)
        a = torch.transpose(b, 0, 1)

    # 1st layer neurons
        l1 = torch.tanh(W1 @ a + b1)

    # last layer
        logits = (W2 @ l1 + b2)
        logits = torch.transpose(logits, 0, 1)
        P = torch.softmax(logits, 1)
        ix = torch.multinomial(P, num_samples=1, replacement=True, generator=g).item()
        s = s[1:] + [ix]
        out.append(itos[ix])
        if ix == 0:
            break
    print("".join(out))
# Out:
# khrish.
# alira.
# juuuz.
# manzer.
# kakai.
# beilgkalrer.
# arabeigsi.
# haenax.
# jule.
# shonles.

# %%
plt.figure(figsize=(6,6))
plt.scatter(C[:,0].data, C[:,1].data, s=100)
for i in range(C.shape[0]):
    if itos[i] in ["a", "e", "i", "o", "u"]:
        plt.text(C[i,0].item(), C[i,3].item(), itos[i], ha="center", va = "center", color = "red")
    else:
        plt.text(C[i,0].item(), C[i,1].item(), itos[i], ha="center", va = "center", color = "white")
plt.grid('minor')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[666], line 5
#       3 for i in range(C.shape[0]):
#       4     if itos[i] in ["a", "e", "i", "o", "u"]:
# ----> 5         plt.text(C[i,0].item(), C[i,3].item(), itos[i], ha="center", va = "center", color = "red")
#       6     else:
#       7         plt.text(C[i,0].item(), C[i,1].item(), itos[i], ha="center", va = "center", color = "white")
#
# IndexError: index 3 is out of bounds for dimension 1 with size 3
